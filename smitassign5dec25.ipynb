# %%
import pandas as pd

# Load the dataset (assuming it is saved as 'Cardiovascular_Disease_Dataset.csv')
df = pd.read_csv('Cardiovascular_Disease_Dataset.csv')

# %%
print(df.head())
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
print(df.shape)
# Out:
# (1000, 14)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientid          1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   int64
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 109.5 KB
# None

# %%
print(df.isnull().sum())
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.describe())
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# ...

# %%
print("Student Name = Arshad Ali")
print ("Enrolled Course = AI & Data Science")
print ("Roll # = 403515")
print("Class Teacher = Sir Yasir Nawaz Memon")
print ("Campus = SMIT Memon Society Qasimabad Hyderabad")
print("Heart Disease Prediction Using Machine Learning")
print("Course: Artificial Intelligence / Data Science")
print("Topic: Classification Models for Cardiovascular Disease Prediction")
print("Dataset: Mendeley Cardiovascular Disease Dataset")
print("Task 1: Data Loading and Exploration \nTask 2: Data Pre-processing \nTask 3: Logistic Regression (Tuned) \nTask 5: Random Forest Classifier (Tuned) \nTask 6: Model Comparison and Evaluation")

import pandas as pd
data = pd.read_csv('Cardiovascular_Disease_Dataset.csv')
data
# Out:
# Student Name = Arshad Ali
# Enrolled Course = AI & Data Science
# Roll # = 403515
# Class Teacher = Sir Yasir Nawaz Memon
# Campus = SMIT Memon Society Qasimabad Hyderabad
# Heart Disease Prediction Using Machine Learning
# Course: Artificial Intelligence / Data Science
# Topic: Classification Models for Cardiovascular Disease Prediction
# Dataset: Mendeley Cardiovascular Disease Dataset
# Task 1: Data Loading and Exploration
# Task 2: Data Pre-processing
# Task 3: Logistic Regression (Tuned)
# Task 5: Random Forest Classifier (Tuned)
# Task 6: Model Comparison and Evaluation
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# ...

# %%
data.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientid          1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   int64
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 109.5 KB

# %%
data.isnull().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# ...

# %%
# Explanation:
# Features: Each feature in the dataset represents a medical attribute like age, gender, blood pressure, cholesterol levels, etc.
# Target Variable: The target variable is the binary classification column that indicates the presence (1) or absence (0) of cardiovascular disease.

# %%
print("Task 2: Data Preprocessing")

# Handling missing values:
# missing values can be drop or fill the missing values
# For numeric columns, you can fill missing values with the median or mean:

##data.fillna(data.median(), inplace=True)

# For categorical columns, you can fill with the mode or drop:

##data['categorical_column'].fillna(data['categorical_column'].mode()[0], inplace=True)

# Encoding categorical variables:
# If there are any categorical variables
# (e.g., gender or smoking status), you can use one-hot encoding or label encoding:

##data = pd.get_dummies(data, drop_first=True)

# Separating features (X) and target variable (y):

X = data.drop('target', axis=1)
y = data['target']

# Scaling features using StandardScaler:
# Feature scaling is important one, especially for models like Logistic Regression,
# as they rely on the magnitude of the features. Logistic regression uses distance-based
# metrics, so unscaled features may lead to biased results.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset into training and testing sets:

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Out:
# Task 2: Data Preprocessing

# %%
print ("Task 3: Logistic Regression with Hyperparameter Tuning")

# Logistic Regression Model:

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# Hyperparameter Tuning using GridSearchCV:

from sklearn.model_selection import GridSearchCV
param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l2'],
    'solver': ['liblinear']
}
grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Evaluate model performance:

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
y_pred = grid_search.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print(f"Confusion Matrix:\n{cm}")

print("Explanation of Metrics:")
print("Accuracy: Proportion of correct predictions out of total predictions.")
print("Precision: How many of the predicted positives are actually positive.")
print("Recall: How many actual positives were correctly identified.")
print("F1-score: Harmonic mean of Precision and Recall, balancing both.")
# Out:
# Task 3: Logistic Regression with Hyperparameter Tuning
# Accuracy: 0.97
# Precision: 0.9751552795031055
# Recall: 0.9691358024691358
# F1-score: 0.9721362229102167
# Confusion Matrix:
# [[134   4]
#  [  5 157]]
# Explanation of Metrics:
# Accuracy: Proportion of correct predictions out of total predictions.
# Precision: How many of the predicted positives are actually positive.
# Recall: How many actual positives were correctly identified.
# F1-score: Harmonic mean of Precision and Recall, balancing both.

# %%
print("Task 4: Decision Tree Classifier")

# Train a Decision Tree Classifier:
from sklearn.tree import DecisionTreeClassifier
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train, y_train)

#Hyperparameter Tuning:
param_grid_tree = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 10, 20],
    'criterion': ['gini', 'entropy']
}
grid_search_tree = GridSearchCV(DecisionTreeClassifier(), param_grid_tree, cv=5)
grid_search_tree.fit(X_train, y_train)

# Evaluate Model Performance:
y_pred_tree = grid_search_tree.predict(X_test)
accuracy_tree = accuracy_score(y_test, y_pred_tree)
cm_tree = confusion_matrix(y_test, y_pred_tree)
print(f"Accuracy: {accuracy_tree}")
print(f"Confusion Matrix:\n{cm_tree}")

print("Advantages & Disadvantages of Decision Trees:")
print("Advantages: Easy to interpret, handles both numerical and categorical data.")
print("Disadvantages: Prone to overfitting, sensitive to noise.")
# Out:
# Task 4: Decision Tree Classifier
# Accuracy: 0.9766666666666667
# Confusion Matrix:
# [[132   6]
#  [  1 161]]
# Advantages & Disadvantages of Decision Trees:
# Advantages: Easy to interpret, handles both numerical and categorical data.
# Disadvantages: Prone to overfitting, sensitive to noise.

# %%
print("Task 5: Random Forest Classifier")

# Train a Random Forest Classifier:
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

# Hyperparameter Tuning:
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 10, 20]
}
grid_search_rf = GridSearchCV(RandomForestClassifier(), param_grid_rf, cv=5)
grid_search_rf.fit(X_train, y_train)

# Evaluate Model Performance:
y_pred_rf = grid_search_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
cm_rf = confusion_matrix(y_test, y_pred_rf)
print(f"Accuracy: {accuracy_rf}")
print(f"Confusion Matrix:\n{cm_rf}")

# Plot Feature Importance:
import matplotlib.pyplot as plt
feature_importance = rf_model.feature_importances_
features = X.columns
plt.barh(features, feature_importance)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.show()

print("Explanation:")
print("Random Forest performs better than a single Decision Tree because it reduces overfitting ")
print("by averaging multiple trees' predictions, providing a more generalizable model.")
# Out:
# Task 5: Random Forest Classifier
# Accuracy: 0.98
# Confusion Matrix:
# [[135   3]
#  [  3 159]]
# Explanation:
# Random Forest performs better than a single Decision Tree because it reduces overfitting
# by averaging multiple trees' predictions, providing a more generalizable model.

# %%
print ("Task 6: Model Comparison")

# Comparison Table:
# Create a comparison table of metrics (Accuracy, Precision, Recall, F1-score) for each model. You can use pandas to create this table:

# For Logistic Regression
y_pred_lr = grid_search.predict(X_test)
accuracy_lr = accuracy_score(y_test, y_pred_lr)
precision_lr = precision_score(y_test, y_pred_lr)
recall_lr = recall_score(y_test, y_pred_lr)
f1_lr = f1_score(y_test, y_pred_lr)

# For Decision Tree
y_pred_tree = grid_search_tree.predict(X_test)
accuracy_tree = accuracy_score(y_test, y_pred_tree)
precision_tree = precision_score(y_test, y_pred_tree)
recall_tree = recall_score(y_test, y_pred_tree)
f1_tree = f1_score(y_test, y_pred_tree)

# For Random Forest
y_pred_rf = grid_search_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)

#the comparison table with all metrics
import pandas as pd

comparison = pd.DataFrame({
    'Model': ['Logistic Regression', 'Decision Tree', 'Random Forest'],
    'Accuracy': [accuracy_lr, accuracy_tree, accuracy_rf],
    'Precision': [precision_lr, precision_tree, precision_rf],
    'Recall': [recall_lr, recall_tree, recall_rf],
    'F1-score': [f1_lr, f1_tree, f1_rf]
})

print(comparison)


# Discussion:
# Best Model: The model with the highest F1-score or precision, depending on which metric you prioritize for heart disease prediction.

# Recommendation: Consider Random Forest or Logistic Regression based on trade-offs between complexity and interpretability.

# Risks of False Negatives: In the case of heart disease, a false negative could mean a patient who has the disease but is misclassified as healthy, potentially leading to a lack of intervention and increased risk of heart attack or death.
# Out:
# Task 6: Model Comparison
#                  Model  Accuracy  Precision    Recall  F1-score
# 0  Logistic Regression  0.970000   0.975155  0.969136  0.972136
# 1        Decision Tree  0.976667   0.964072  0.993827  0.978723
# 2        Random Forest  0.980000   0.981481  0.981481  0.981481

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 1. Identify and select the best model's predictions based on Accuracy
best_model_name = comparison.loc[comparison['Accuracy'].idxmax(), 'Model']
predictions_map = {
    'Logistic Regression': y_pred_lr,
    'Decision Tree': y_pred_tree,
    'Random Forest': y_pred_rf
}
best_preds = predictions_map[best_model_name]

# 2. Generate and plot the Confusion Matrix
cm = confusion_matrix(y_test, best_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot(cmap=plt.cm.Blues)
plt.title(# Standard Visualization
    f'Confusion Matrix: {best_model_name}')
plt.show()


print ("Assignment submitted, Hope for the good result")
# Out:
# Assignment submitted, Hope for the good result
